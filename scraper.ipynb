# %%
import os
import numpy as np
import concurrent.futures
from pymongo import MongoClient
from pprint import pprint
from time import sleep
import random
from copy import deepcopy
import requests

#local helper files
from helpers import get_proxy_list, format_proxy 
from extractors import get_data 
import settings

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys

chromedriver = "/Applications/chromedriver" # path to the chromedriver executable
os.environ["webdriver.chrome.driver"] = chromedriver

# %% [markdown]
# #### Pull listing_url documents from mongoDB

# %%
db = MongoClient().get_database('philadelphia_home_prices')

# %%
col = db.get_collection('listing_urls')

# %%
cursor = db.listing_urls.find({})
listings = list(cursor)

# %%
#convert dictionary values to list
listing_urls_list = []
for i in listings:
    url = i['url']
    listing_urls_list.append(url)

# %% [markdown]
# #### New collection for listing data

# %%
db.list_collection_names()
# Out:
# ['prices_messy', 'listing_data', 'listing_urls']

# %%
#uncomment the code you need to use during testing
#db.drop_collection('listing_data')
#db.create_collection('listing_data')

# %%
col = db.get_collection('listing_data')

# %%
#check number of documents in collection
col.count_documents({})
# Out:
# 1101

# %% [markdown]
# #### Pick which urls in list by index

# %%
#initiate empty lists
scraped_urls = []
bad_proxies = []
bad_urls = []

# %%
#only run once
remaining_listing_urls_list = deepcopy(listing_urls_list)

# %%
#code for each scrape
def scrape_requests(url):
    listing_data = {}
    try:
        PROXY = random.choice(proxies_address) #pick random proxy from list
        proxies_address.remove(PROXY) #checkout proxy
        proxies = format_proxy(PROXY) 

        headers = settings.headers

       
        try: 
            response = requests.get(url,headers=headers,proxies=proxies) #page request
        except:
            response = False
            
        soup = BeautifulSoup(response.text, 'html.parser')
        listing_data = get_data(soup, url)

        sleep(random.uniform(60,120))
        
        #check if scrape was successful. Then move url out
        if response.status_code == 200 and listing_data['Address'] != np.nan:
            scraped_urls.append(url)
            remaining_listing_urls_list.remove(url)
            col.insert_one(listing_data)
            proxies_address.append(PROXY)
            print(listing_data)
    
    except:
        if response == False:
            bad_proxies.append(PROXY) #remove proxy if no response from page
            print('no response, bad proxy')
        elif response.status_code != 200: #remove proxy if not 200 response from page
            bad_proxies.append(PROXY)
            print('not 200, bad proxy')
        else:
            bad_urls.append(url) #quarantine url that is not functioning
            remaining_listing_urls_list.remove(url)
    
    print('______________________________________________________')
    print(f'   Remaining urls: {len(remaining_listing_urls_list)}')
    print(f'     Scraped urls: {len(scraped_urls)}')
    print(f'Good proxies left: {len(proxies_address)}')
    print(f'      Bad proxies: {len(bad_proxies)}')
    
    #space out requests if there are a low number of proxies left
    if len(proxies_address) < 100:
        sleep(random.uniform(60,120))
        
    return

# %%
#multi-thread with concurrent.features
def threaded_scrape(remaining_listing_urls_list, threads):
    threads = min(threads, len(proxies_address))
    
    with concurrent.futures.ThreadPoolExecutor(max_workers=threads) as executor:
        executor.map(scrape_requests, remaining_listing_urls_list)

# %%
count = 0
while len(remaining_listing_urls_list) > 0:
    if count%5 == 0:
        proxies_address = get_proxy_list() #Get free proxies from https://free-proxy-list.net/¶
    threaded_scrape(remaining_listing_urls_list, settings.threads)
    count =+ 1
    print('new round of proxies')
    print(f'   Remaining urls: {len(remaining_listing_urls_list)}')
    print(f'     Scraped urls: {len(scraped_urls)}')
# Out:
# 2020-11-09 15:17:27,320 root   DEBUG    === Initialized Proxy Parsers ===
# 2020-11-09 15:17:27,320 root   DEBUG    	 FreeProxy parser of 'http://free-proxy-list.net' with required bandwidth: '150' KBs
# 2020-11-09 15:17:27,321 root   DEBUG    	 PremProxy parser of 'https://premproxy.com/list/' with required bandwidth: '150' KBs
# 2020-11-09 15:17:27,321 root   DEBUG    =================================
# 2020-11-09 15:17:27,721 root   DEBUG    Added 300 proxies from FreeProxy
# 2020-11-09 15:17:28,325 http_request_randomizer.requests.parsers.PremProxyParser DEBUG    Pages: {'', '04.htm', '07.htm', '06.htm', '03.htm', '05.htm', '02.htm'}
# 2020-11-09 15:17:28,907 http_request_randomizer.requests.parsers.js.UnPacker INFO     JS UnPacker init path: https://premproxy.com/js/169f7.js
# 2020-11-09 15:17:29,462 http_request_randomizer.requests.parsers.js.UnPacker DEBUG    portmap: {'ra3a4': '8080', 're660': '8088', 'r1b47': '8000', 'rac76': '3128', 'r796a': '9999', 'r32b4': '999', 'r56b1': '50616', 'r2007': '34930', 'r9b25': '80', 'rd711': '8888', 'rfade': '51915', 'r3460': '63141', 'r8e2f': '35709', 'rbca7': '32231', 'r5f3b': '57797', 'rf0b3': '53281', 'rd7ba': '33630', 'rf277': '8081', 'rb282': '59152', 'r76d0': '43388', 'ra1a8': '41878', 'r961d': '45521', 'r7a99': '36182', 'rbe2f': '55443', 'r7e32': '39150', 'r68df': '3129', 'ra4db': '49073', 'r1005': '38746', 'rfc28': '3000', 'r474f': '34403', 'r325d': '3838', 'r8f9e': '55870', 'r8ae3': '2020', 'r92da': '49929', 'r97e9': '42119', 'r1523': '51489', 'r587d': '61279', 'r0bf7': '8193', 'r770a': '8382', 'rf267': '54621', 'rca8e': '83', 'ra943': '54754', 'r1c57': '60306', 'r41ea': '8181', 'r0f73': '9090', 'r2247': '8686', 'rb3b4': '55725', 'rd86f': '32052', 're925': '42535', 'r6689': '34577', 'rd765': '1234', 'rfc29': '8090', 'rdf10': '2222', 'r12ae': '48458', 'rb8ee': '48515', 'r85e0': '54018', 'r5443': '3127', 'rd5e0': '52271', 'r1fd2': '4645', 'r0ad6': '43631', 'rdc12': '54555', 'ra43b': '23500', 'r901e': '61954', 'r308c': '45871', 'r7fdd': '31984', 'r52d5': '47548', 'rb76f': '46340', 'r5fd9': '48687', 'rdd80': '47029', 'r6e38': '50330', 'r9d1c': '8082', 'ra85a': '443', 'r1bfd': '38510', 'r5b58': '41868', 'r1aa5': '53480', 'r64aa': '57628', 'r056e': '8118', 'r69dc': '55693', 'rf840': '58198', 'r8424': '45759', 're646': '46944', 'r3283': '3133', 'r8177': '1981', 'r08dc': '42113', 'r6c54': '58302', 'rc245': '32180', 're1d3': '8085', 'r8e02': '54675', 'r7029': '47504'}
# 2020-11-09 15:17:33,666 root   DEBUG    Added 321 proxies from PremProxy
# 2020-11-09 15:17:33,667 root   DEBUG    Total proxies = 621
# 2020-11-09 15:17:33,667 root   DEBUG    Filtered proxies = 621
# no response, bad proxy
# ______________________________________________________
#    Remaining urls: 1100
#      Scraped urls: 0
# Good proxies left: 553
#       Bad proxies: 1
# no response, bad proxy
# ______________________________________________________
#    Remaining urls: 1100
#      Scraped urls: 0
# Good proxies left: 552
#       Bad proxies: 2
# no response, bad proxy
# ______________________________________________________
#    Remaining urls: 1100
#      Scraped urls: 0
# Good proxies left: 551
#       Bad proxies: 3
# no response, bad proxy
# ______________________________________________________
#    Remaining urls: 1100
#      Scraped urls: 0
# Good proxies left: 550
#       Bad proxies: 4
# no response, bad proxy
# ______________________________________________________
#    Remaining urls: 1100
#      Scraped urls: 0
# Good proxies left: 549
#       Bad proxies: 5
# no response, bad proxy
# ______________________________________________________
#    Remaining urls: 1100
#      Scraped urls: 0
# Good proxies left: 548
#       Bad proxies: 6
# no response, bad proxy
# ______________________________________________________
#    Remaining urls: 1100
#      Scraped urls: 0
# Good proxies left: 547
#       Bad proxies: 7
# no response, bad proxy
# ______________________________________________________
#    Remaining urls: 1100
#      Scraped urls: 0
# Good proxies left: 546
#       Bad proxies: 8
# no response, bad proxy
# ______________________________________________________
#    Remaining urls: 1100
#      Scraped urls: 0
# Good proxies left: 545
#       Bad proxies: 9
# no response, bad proxy
# ______________________________________________________
#    Remaining urls: 1100
#      Scraped urls: 0
# Good proxies left: 544
#       Bad proxies: 10
# no response, bad proxy
# ______________________________________________________
#    Remaining urls: 1100
#      Scraped urls: 0
# Good proxies left: 543
#       Bad proxies: 11
# no response, bad proxy
# ______________________________________________________
#    Remaining urls: 1100
#      Scraped urls: 0
# Good proxies left: 542
#       Bad proxies: 12
# no response, bad proxy
# ______________________________________________________
#    Remaining urls: 1100
#      Scraped urls: 0
# Good proxies left: 541
#       Bad proxies: 13
# no response, bad proxy
# ______________________________________________________
#    Remaining urls: 1100
#      Scraped urls: 0
# Good proxies left: 540
#       Bad proxies: 14
# no response, bad proxy
# ______________________________________________________
#    Remaining urls: 1100
#      Scraped urls: 0
# Good proxies left: 539
#       Bad proxies: 15
# no response, bad proxyno response, bad proxyno response, bad proxyno response, bad proxyno response, bad proxyno response, bad proxy
# ______________________________________________________
#    Remaining urls: 1100
#      Scraped urls: 0
# Good proxies left: 538
# no response, bad proxy
#
# ______________________________________________________
#    Remaining urls: 1099
#      Scraped urls: 1
# Good proxies left: 538
#       Bad proxies: 22
# no response, bad proxyno response, bad proxyno response, bad proxy______________________________________________________no response, bad proxy      Bad proxies: 26
# ______________________________________________________
#    Remaining urls: 1099
#      Scraped urls: 1
# Good proxies left: 537
#
# ______________________________________________________
#    Remaining urls: 1099
#      Scraped urls: 1
# Good proxies left: 537
#       Bad proxies: 26
# no response, bad proxy
#
# no response, bad proxy      Bad proxies: 28no response, bad proxyno response, bad proxy
#
# no response, bad proxy
#
# ______________________________________________________
# no response, bad proxy
#
#    Remaining urls: 1099
#
#
#
# ____________________________________________________________________________________________________________
#
# ______________________________________________________
#    Remaining urls: 1099
#      Scraped urls: 1
# Good proxies left: 534
#       Bad proxies: 32
#      Scraped urls: 1
#
# Good proxies left: 533
#       Bad proxies: 32
#
# ____________________________________________________________________________________________________________
#    Remaining urls: 1098
#      Scraped urls: 2
# Good proxies left: 532
#       Bad proxies: 32
# ______________________________________________________   Remaining urls: 1098no response, bad proxy______________________________________________________
# ______________________________________________________   Remaining urls: 1098
# no response, bad proxy
# no response, bad proxy
# ______________________________________________________
#    Remaining urls: 1098
#      Scraped urls: 2
# Good proxies left: 531
#       Bad proxies: 35
#
#    Remaining urls: 1098
#
# ______________________________________________________   Remaining urls: 1098
#
#      Scraped urls: 2
# Good proxies left: 530
#       Bad proxies: 35
#    Remaining urls: 1098   Remaining urls: 1098
#
# ______________________________________________________
#    Remaining urls: 1098
#      Scraped urls: 2
# Good proxies left: 529
#       Bad proxies: 35
#
#      Scraped urls: 2     Scraped urls: 2
# Good proxies left: 528
#       Bad proxies: 35
#      Scraped urls: 2
#      Scraped urls: 2______________________________________________________
# Good proxies left: 527
#       Bad proxies: 35
#    Remaining urls: 1098
#
#      Scraped urls: 2
# Good proxies left: 526
#       Bad proxies: 35
#      Scraped urls: 2
#
# no response, bad proxy
#    Remaining urls: 1098
#
# ______________________________________________________   Remaining urls: 1098
#
# ______________________________________________________
#
# Good proxies left: 525Good proxies left: 525
# ______________________________________________________     Scraped urls: 2
# Good proxies left: 525
#       Bad proxies: 36
#    Remaining urls: 1098
#      Scraped urls: 2Good proxies left: 524
#
#
#    Remaining urls: 1098
#
#    Remaining urls: 1098
#
#       Bad proxies: 36Good proxies left: 524     Scraped urls: 2      Bad proxies: 36
#      Scraped urls: 2
#      Scraped urls: 2      Bad proxies: 36
# Good proxies left: 524
#       Bad proxies: 36
#
#
# {'Address': '2941 Wilder St,', 'Locality': 'Philadelphia', 'Region': 'PA', 'Postal Code': '19146', 'Price': 125000, 'Days on Market': 31, 'SQFT House': 780, 'SQFT Lot': 672, 'Full Baths': 1, 'Half Baths': 0, 'Bedrooms': 3, 'Garage': 'No', 'Master Bath': 'No', 'Cooling': 'No', 'Heating': ['Forced Air Heating', 'Yes', 'Yes'], 'Annual Tax': 1116, 'House Type': [' Interior Row/Townhouse', ' Multi family'], 'Build Year': 1925, 'Remodel Year': 2020, 'Neighborhood': 'Grays Ferry', 'Neighborhood median sales': 166000, 'Neighborhood Median DOM': 65, 'Neighborhood Price SQFT': 186, 'Association': 'No', 'Association Monthly': 0, 'URL': 'https://www.realtor.com/realestateandhomes-detail/2941-Wilder-St_Philadelphia_PA_19146_M49338-11081', 'crawl time': datetime.datetime(2020, 11, 9, 15, 17, 52, 144086), '_id': ObjectId('5fa9c04ecdfd30c30a7f4bd6')}
#
# ______________________________________________________
#    Remaining urls: 1098
#      Scraped urls: 2
# Good proxies left: 523
#       Bad proxies: 36
#
#
# Good proxies left: 521
#       Bad proxies: 36
#       Bad proxies: 36{'Address': '2046 W Laurel St Unit 1,', 'Locality': 'Philadelphia', 'Region': 'PA', 'Postal Code': '19123', 'Price': 1240000, 'Days on Market': 223, 'SQFT House': 4000, 'SQFT Lot': 0, 'Full Baths': 3, 'Half Baths': 1, 'Bedrooms': 4, 'Garage': [' 2'], 'Master Bath': 'No', 'Cooling': ['Central A/C, Zoned Cooling'], 'Heating': ['Forced Air Heating', 'Yes'], 'Annual Tax': 'Not Found', 'House Type': [' Interior Row/Townhouse'], 'Build Year': 2015, 'Remodel Year': 'Not Updated', 'Neighborhood': 'Not Found', 'Neighborhood median sales': 250000, 'Neighborhood Median DOM': 63, 'Neighborhood Price SQFT': 195, 'Association': 'Yes', 'Association Monthly': 104, 'URL': 'https://www.realtor.com/realestateandhomes-detail/2046-W-Laurel-St-Unit-1_Philadelphia_PA_19123_M97809-07446', 'crawl time': datetime.datetime(2020, 11, 9, 15, 17, 45, 641045), '_id': ObjectId('5fa9c050cdfd30c30a7f4bd7')}
# Good proxies left: 520
# ______________________________________________________
#
# no response, bad proxy      Bad proxies: 37
# ______________________________________________________
#    Remaining urls: 1098
#      Scraped urls: 2
# Good proxies left: 519
#    Remaining urls: 1098
#       Bad proxies: 37
# no response, bad proxy
# ______________________________________________________
#    Remaining urls: 1098
#      Scraped urls: 2
# Good proxies left: 518
#       Bad proxies: 38
# no response, bad proxy
#      Scraped urls: 2no response, bad proxy
# Good proxies left: 516
#       Bad proxies: 40
# ______________________________________________________
#    Remaining urls: 1098
#      Scraped urls: 2
# Good proxies left: 515
#       Bad proxies: 40
#
# ______________________________________________________
#    Remaining urls: 1098
#      Scraped urls: 2
# Good proxies left: 514
#       Bad proxies: 40
# no response, bad proxy
# ______________________________________________________
#    Remaining urls: 1098
#      Scraped urls: 2
# Good proxies left: 513
#       Bad proxies: 41
# no response, bad proxy
# ______________________________________________________
#    Remaining urls: 1098
#      Scraped urls: 2
# Good proxies left: 512
#       Bad proxies: 42
# {'Address': '1918 S Juniper St,', 'Locality': 'Philadelphia', 'Region': 'PA', 'Postal Code': '19148', 'Price': 318000, 'Days on Market': 76, 'SQFT House': 1096, 'SQFT Lot': 713, 'Full Baths': 1, 'Half Baths': 1, 'Bedrooms': 3, 'Garage': 'No', 'Master Bath': 'No', 'Cooling': ['Wall Unit Cooling'], 'Heating': ['Radiator', 'Yes', 'Unknown'], 'Annual Tax': 3690, 'House Type': [' End of Row/Townhouse', ' Multi family'], 'Build Year': 1925, 'Remodel Year': 2020, 'Neighborhood': 'East Passyunk', 'Neighborhood median sales': 250000, 'Neighborhood Median DOM': 63, 'Neighborhood Price SQFT': 195, 'Association': 'No', 'Association Monthly': 0, 'URL': 'https://www.realtor.com/realestateandhomes-detail/1918-S-Juniper-St_Philadelphia_PA_19148_M47175-08727', 'crawl time': datetime.datetime(2020, 11, 9, 15, 18, 4, 126168), '_id': ObjectId('5fa9c05ccdfd30c30a7f4bd8')}
# ______________________________________________________
#    Remaining urls: 1097
#      Scraped urls: 3
# Good proxies left: 512
#       Bad proxies: 42
# no response, bad proxy
# ______________________________________________________
#    Remaining urls: 1097
#      Scraped urls: 3
# Good proxies left: 511no response, bad proxy
#
#       Bad proxies: 44no response, bad proxy______________________________________________________
#
#    Remaining urls: 1097
# ______________________________________________________
#
# no response, bad proxy   Remaining urls: 1095     Scraped urls: 5
#
#
# ______________________________________________________
#    Remaining urls: 1095
#      Scraped urls: 5
# Good proxies left: 510
#       Bad proxies: 46
# Good proxies left: 509
# {'Address': '2863 Norcom Rd,', 'Locality': 'Philadelphia', 'Region': 'PA', 'Postal Code': '19154', 'Price': 279000, 'Days on Market': 26, 'SQFT House': 1788, 'SQFT Lot': 9520, 'Full Baths': 2, 'Half Baths': 0, 'Bedrooms': 4, 'Garage': 'No', 'Master Bath': 'No', 'Cooling': ['Wall Unit Cooling, Window Unit'], 'Heating': ['Baseboard ', 'Yes'], 'Annual Tax': 3465, 'House Type': [' Detached', ' Single family'], 'Build Year': 1956, 'Remodel Year': 2020, 'Neighborhood': 'Normandy Village', 'Neighborhood median sales': 'Not Found', 'Neighborhood Median DOM': 'Not Found', 'Neighborhood Price SQFT': 211, 'Association': 'No', 'Association Monthly': 0, 'URL': 'https://www.realtor.com/realestateandhomes-detail/2863-Norcom-Rd_Philadelphia_PA_19154_M49017-96853', 'crawl time': datetime.datetime(2020, 11, 9, 15, 18, 12, 358839), '_id': ObjectId('5fa9c063cdfd30c30a7f4bd9')}     Scraped urls: 5
# Good proxies left: 510
#       Bad proxies: 46
#
# ______________________________________________________
#    Remaining urls: 1095
#       Bad proxies: 46     Scraped urls: 5
#
# Good proxies left: 508
#       Bad proxies: 46
# {'Address': '1211 E Cheltenham Ave,', 'Locality': 'Philadelphia', 'Region': 'PA', 'Postal Code': '19124', 'Price': 100000, 'Days on Market': 44, 'SQFT House': 1110, 'SQFT Lot': 1080, 'Full Baths': 1, 'Half Baths': 0, 'Bedrooms': 3, 'Garage': 'No', 'Master Bath': 'No', 'Cooling': 'No', 'Heating': ['Hot Water', 'Yes', 'Hot Water'], 'Annual Tax': 1257, 'House Type': [' Interior Row/Townhouse', ' Multi family'], 'Build Year': 1950, 'Remodel Year': 2020, 'Neighborhood': 'Summerdale', 'Neighborhood median sales': 'Not Found', 'Neighborhood Median DOM': 'Not Found', 'Neighborhood Price SQFT': 120, 'Association': 'No', 'Association Monthly': 0, 'URL': 'https://www.realtor.com/realestateandhomes-detail/1211-E-Cheltenham-Ave_Philadelphia_PA_19124_M33700-20336', 'crawl time': datetime.datetime(2020, 11, 9, 15, 17, 40, 447547), '_id': ObjectId('5fa9c065cdfd30c30a7f4bda')}
# ______________________________________________________
#    Remaining urls: 1095
#      Scraped urls: 5
# Good proxies left: 508
#       Bad proxies: 46
# {'Address': '5878 Henry Ave,', 'Locality': 'Philadelphia', 'Region': 'PA', 'Postal Code': '19128', 'Price': 260000, 'Days on Market': 63, 'SQFT House': 1242, 'SQFT Lot': 1672, 'Full Baths': 1, 'Half Baths': 1, 'Bedrooms': 3, 'Garage': 'No', 'Master Bath': 'No', 'Cooling': ['Window Unit'], 'Heating': ['Hot Water', 'Yes', 'Hot Water'], 'Annual Tax': 3022, 'House Type': [' Interior Row/Townhouse', ' Multi family'], 'Build Year': 1935, 'Remodel Year': 2020, 'Neighborhood': 'Roxborough', 'Neighborhood median sales': 273750, 'Neighborhood Median DOM': 60, 'Neighborhood Price SQFT': 198, 'Association': 'No', 'Association Monthly': 0, 'URL': 'https://www.realtor.com/realestateandhomes-detail/5878-Henry-Ave_Philadelphia_PA_19128_M36198-59438', 'crawl time': datetime.datetime(2020, 11, 9, 15, 17, 54, 44249), '_id': ObjectId('5fa9c069cdfd30c30a7f4bdb')}
# ______________________________________________________
#    Remaining urls: 1094
#      Scraped urls: 6
# Good proxies left: 508
#       Bad proxies: 46
# no response, bad proxy
# ______________________________________________________
#    Remaining urls: 1094
#      Scraped urls: 6
# Good proxies left: 507
#       Bad proxies: 47
# {'Address': '6128 N 7th St,', 'Locality': 'Philadelphia', 'Region': 'PA', 'Postal Code': '19120', 'Price': 161000, 'Days on Market': 50, 'SQFT House': 2012, 'SQFT Lot': 1440, 'Full Baths': 2, 'Half Baths': 0, 'Bedrooms': 4, 'Garage': [' 1'], 'Master Bath': 'No', 'Cooling': 'No', 'Heating': ['Radiator', 'Yes', 'Unknown'], 'Annual Tax': 1922, 'House Type': [' Interior Row/Townhouse', ' Multi family'], 'Build Year': 1945, 'Remodel Year': 2020, 'Neighborhood': 'Olney', 'Neighborhood median sales': 123000, 'Neighborhood Median DOM': 67, 'Neighborhood Price SQFT': 113, 'Association': 'No', 'Association Monthly': 0, 'URL': 'https://www.realtor.com/realestateandhomes-detail/6128-N-7th-St_Philadelphia_PA_19120_M30359-01965', 'crawl time': datetime.datetime(2020, 11, 9, 15, 18, 31, 834944), '_id': ObjectId('5fa9c07ccdfd30c30a7f4bdc')}
# ______________________________________________________
#    Remaining urls: 1093
#      Scraped urls: 7
# Good proxies left: 507
#       Bad proxies: 47
# {'Address': '3634 Miller St,', 'Locality': 'Philadelphia', 'Region': 'PA', 'Postal Code': '19134', 'Price': 155000, 'Days on Market': 99, 'SQFT House': 717, 'SQFT Lot': 896, 'Full Baths': 1, 'Half Baths': 0, 'Bedrooms': 2, 'Garage': 'No', 'Master Bath': 'No', 'Cooling': ['Central A/C', 'Central'], 'Heating': ['Forced Air Heating', 'Yes', 'Yes'], 'Annual Tax': 1761, 'House Type': [' End of Row/Townhouse', ' Multi family'], 'Build Year': 1955, 'Remodel Year': 2020, 'Neighborhood': 'Richmond', 'Neighborhood median sales': 223950, 'Neighborhood Median DOM': 65, 'Neighborhood Price SQFT': 191, 'Association': 'No', 'Association Monthly': 0, 'URL': 'https://www.realtor.com/realestateandhomes-detail/3634-Miller-St_Philadelphia_PA_19134_M41222-81350', 'crawl time': datetime.datetime(2020, 11, 9, 15, 17, 58, 123752), '_id': ObjectId('5fa9c086cdfd30c30a7f4bdd')}
# ______________________________________________________{'Address': '310 S Front St,', 'Locality': 'Philadelphia', 'Region': 'PA', 'Postal Code': '19106', 'Price': 1850000, 'Days on Market': 65, 'SQFT House': 3523, 'SQFT Lot': 81984, 'Full Baths': 3, 'Half Baths': 1, 'Bedrooms': 4, 'Garage': [' 3'], 'Master Bath': 'No', 'Cooling': ['Central A/C, Zoned Cooling, Programmable Thermostat Cooling, Energy Star Cooling System'], 'Heating': ['Forced Air Heating, Zoned Heating, Programmable Thermostat Heating', 'Yes'], 'Annual Tax': 15849, 'House Type': [' Interior Row/Townhouse', ' Condo'], 'Build Year': 1971, 'Remodel Year': 2020, 'Neighborhood': 'Not Found', 'Neighborhood median sales': 250000, 'Neighborhood Median DOM': 63, 'Neighborhood Price SQFT': 195, 'Association': 'Yes', 'Association Monthly': 616, 'URL': 'https://www.realtor.com/realestateandhomes-detail/310-S-Front-St_Philadelphia_PA_19106_M45281-45249', 'crawl time': datetime.datetime(2020, 11, 9, 15, 18, 18, 703270), '_id': ObjectId('5fa9c088cdfd30c30a7f4bde')}
# ______________________________________________________
#    Remaining urls: 1091
#
#      Scraped urls: 9
# Good proxies left: 508
#       Bad proxies: 47
#    Remaining urls: 1091
#      Scraped urls: 9
# Good proxies left: 507
#       Bad proxies: 47
# no response, bad proxy
# ______________________________________________________
#    Remaining urls: 1091
#      Scraped urls: 9
# Good proxies left: 506
#       Bad proxies: 48
# no response, bad proxy
# ______________________________________________________
#    Remaining urls: 1091
#      Scraped urls: 9
# Good proxies left: 505
# no response, bad proxy      Bad proxies: 50
# ______________________________________________________
#
#    Remaining urls: 1091
#      Scraped urls: 9
# Good proxies left: 505
#       Bad proxies: 50
# no response, bad proxy
# ______________________________________________________
#    Remaining urls: 1090
#      Scraped urls: 10
# Good proxies left: 503{'Address': '818 Lawler St,', 'Locality': 'Philadelphia', 'Region': 'PA', 'Postal Code': '19116', 'Price': 264000, 'Days on Market': 56, 'SQFT House': 1480, 'SQFT Lot': 3397, 'Full Baths': 2, 'Half Baths': 1, 'Bedrooms': 4, 'Garage': 'No', 'Master Bath': 'No', 'Cooling': ['Central A/C'], 'Heating': ['Central Heating, Forced Air Heating', 'Yes'], 'Annual Tax': 3021, 'House Type': [' Twin/Semi-Detached', ' Single family'], 'Build Year': 1962, 'Remodel Year': 2020, 'Neighborhood': 'Somerton', 'Neighborhood median sales': 307000, 'Neighborhood Median DOM': 45, 'Neighborhood Price SQFT': 185, 'Association': 'No', 'Association Monthly': 0, 'URL': 'https://www.realtor.com/realestateandhomes-detail/818-Lawler-St_Philadelphia_PA_19116_M30975-13940', 'crawl time': datetime.datetime(2020, 11, 9, 15, 18, 42, 99932), '_id': ObjectId('5fa9c095cdfd30c30a7f4bdf')}
# ______________________________________________________
#
#       Bad proxies: 51
#    Remaining urls: 1089
# {'Address': '3023 Livingston St,', 'Locality': 'Philadelphia', 'Region': 'PA', 'Postal Code': '19134', 'Price': 133000, 'Days on Market': 46, 'SQFT House': 784, 'SQFT Lot': 863, 'Full Baths': 1, 'Half Baths': 0, 'Bedrooms': 2, 'Garage': 'No', 'Master Bath': 'No', 'Cooling': 'No', 'Heating': ['Forced Air Heating', 'Yes', 'Unknown'], 'Annual Tax': 1748, 'House Type': [' Interior Row/Townhouse', ' Multi family'], 'Build Year': 1920, 'Remodel Year': 2020, 'Neighborhood': 'Richmond', 'Neighborhood median sales': 223950, 'Neighborhood Median DOM': 65, 'Neighborhood Price SQFT': 191, 'Association': 'No', 'Association Monthly': 0, 'URL': 'https://www.realtor.com/realestateandhomes-detail/3023-Livingston-St_Philadelphia_PA_19134_M45930-59526', 'crawl time': datetime.datetime(2020, 11, 9, 15, 18, 8, 474624), '_id': ObjectId('5fa9c099cdfd30c30a7f4be0')}
#      Scraped urls: 11______________________________________________________
# Good proxies left: 504
#    Remaining urls: 1089
#      Scraped urls: 11
# Good proxies left: 504
#       Bad proxies: 51
#
#       Bad proxies: 51
# no response, bad proxyno response, bad proxy
# ______________________________________________________
#    Remaining urls: 1086
#      Scraped urls: 14
# Good proxies left: 502{'Address': '606 E Olney Ave,', 'Locality': 'Philadelphia', 'Region': 'PA', 'Postal Code': '19120', 'Price': 175000, 'Days on Market': 43, 'SQFT House': 1088, 'SQFT Lot': 1760, 'Full Baths': 2, 'Half Baths': 0, 'Bedrooms': 3, 'Garage': 'No', 'Master Bath': 'No', 'Cooling': ['Window Unit'], 'Heating': ['Forced Air Heating', 'Yes'], 'Annual Tax': 1422, 'House Type': [' Interior Row/Townhouse', ' Multi family'], 'Build Year': 1930, 'Remodel Year': 2020, 'Neighborhood': 'Olney', 'Neighborhood median sales': 123000, 'Neighborhood Median DOM': 67, 'Neighborhood Price SQFT': 113, 'Association': 'No', 'Association Monthly': 0, 'URL': 'https://www.realtor.com/realestateandhomes-detail/606-E-Olney-Ave_Philadelphia_PA_19120_M44163-32382', 'crawl time': datetime.datetime(2020, 11, 9, 15, 18, 25, 583402), '_id': ObjectId('5fa9c09fcdfd30c30a7f4be1')}
#       Bad proxies: 53
#
#
# ______________________________________________________
#    Remaining urls: 1086
#      Scraped urls: 14
# Good proxies left: 502
#       Bad proxies: 53
# ______________________________________________________
#    Remaining urls: 1086
#      Scraped urls: 14
# Good proxies left: 502
#       Bad proxies: 53
# {'Address': '1232 N Mascher St Unit A,', 'Locality': 'Philadelphia', 'Region': 'PA', 'Postal Code': '19122', 'Price': 639900, 'Days on Market': 37, 'SQFT House': 3188, 'SQFT Lot': 960, 'Full Baths': 3, 'Half Baths': 0, 'Bedrooms': 3, 'Garage': [' 1'], 'Master Bath': 'No', 'Cooling': ['Central A/C', 'Central'], 'Heating': ['Forced Air Heating', 'Yes', 'Yes'], 'Annual Tax': 2056, 'House Type': [' End of Row/Townhouse', ' Multi family'], 'Build Year': 2015, 'Remodel Year': 2020, 'Neighborhood': 'Old Kensington', 'Neighborhood median sales': 250000, 'Neighborhood Median DOM': 63, 'Neighborhood Price SQFT': 195, 'Association': 'Yes', 'Association Monthly': 172, 'URL': 'https://www.realtor.com/realestateandhomes-detail/1232-N-Mascher-St-Apt-A_Philadelphia_PA_19122_M49182-95881', 'crawl time': datetime.datetime(2020, 11, 9, 15, 19, 4, 392445), '_id': ObjectId('5fa9c09fcdfd30c30a7f4be3')}
# ______________________________________________________
#    Remaining urls: 1086
#      Scraped urls: 14
# Good proxies left: 501
#       Bad proxies: 53
# {'Address': '1307 S 17th St,', 'Locality': 'Philadelphia', 'Region': 'PA', 'Postal Code': '19146', 'Price': 524900, 'Days on Market': 84, 'SQFT House': 2960, 'SQFT Lot': 992, 'Full Baths': 3, 'Half Baths': 1, 'Bedrooms': 3, 'Garage': 'No', 'Master Bath': 'No', 'Cooling': ['Central A/C', 'Central'], 'Heating': ['Forced Air Heating', 'Yes', 'Yes'], 'Annual Tax': 1015, 'House Type': [' Interior Row/Townhouse', ' Multi family'], 'Build Year': 2014, 'Remodel Year': 2020, 'Neighborhood': 'Point Breeze', 'Neighborhood median sales': 345000, 'Neighborhood Median DOM': 69, 'Neighborhood Price SQFT': 226, 'Association': 'No', 'Association Monthly': 0, 'URL': 'https://www.realtor.com/realestateandhomes-detail/1307-S-17th-St_Philadelphia_PA_19146_M39955-53546', 'crawl time': datetime.datetime(2020, 11, 9, 15, 19, 8, 419147), '_id': ObjectId('5fa9c09fcdfd30c30a7f4be2')}
# ______________________________________________________
#    Remaining urls: 1086
#      Scraped urls: 14
# Good proxies left: 501
#       Bad proxies: 53
# no response, bad proxy
# ______________________________________________________
#    Remaining urls: 1086
#      Scraped urls: 14
# Good proxies left: 500
#       Bad proxies: 54
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-1c8744dd002d> in <module>
#       3     if count%5 == 0:
#       4         proxies_address = get_proxy_list() #Get free proxies from https://free-proxy-list.net/¶
# ----> 5     threaded_scrape(remaining_listing_urls_list, settings.threads)
#       6     count =+ 1
#       7     print('new round of proxies')
#
# <ipython-input-14-960f919b73a9> in threaded_scrape(remaining_listing_urls_list, threads)
#       4
#       5     with concurrent.futures.ThreadPoolExecutor(max_workers=threads) as executor:
# ----> 6         executor.map(scrape_requests, remaining_listing_urls_list)
#
# ~/opt/anaconda3/lib/python3.7/concurrent/futures/_base.py in __exit__(self, exc_type, exc_val, exc_tb)
#     621
#     622     def __exit__(self, exc_type, exc_val, exc_tb):
# --> 623         self.shutdown(wait=True)
#     624         return False
#     625
#
# ~/opt/anaconda3/lib/python3.7/concurrent/futures/thread.py in shutdown(self, wait)
#     214         if wait:
#     215             for t in self._threads:
# --> 216                 t.join()
#     217     shutdown.__doc__ = _base.Executor.shutdown.__doc__
#
# ~/opt/anaconda3/lib/python3.7/threading.py in join(self, timeout)
#    1042
#    1043         if timeout is None:
# -> 1044             self._wait_for_tstate_lock()
#    1045         else:
#    1046             # the behavior of a negative timeout isn't documented, but
#
# ~/opt/anaconda3/lib/python3.7/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1058         if lock is None:  # already determined that the C code is done
#    1059             assert self._is_stopped
# -> 1060         elif lock.acquire(block, timeout):
#    1061             lock.release()
#    1062             self._stop()
#
# KeyboardInterrupt:
